# %%
15 + 1
# Out:
# 16

# %%
#123 == (3* 10^0) + (2 * 10^1) + (1 * 10^2)

# %%
bin(13) # = (1 * 2^0) + (0 * 2^1) + (1 * 2^2) + (1 * 2^3)
# Out:
# '0b1101'

# %%
hex(13)
# Out:
# '0xd'

# %%
hex(1280)
# Out:
# '0x500'

# %%
5 ** 2
# Out:
# 25

# %%
12 ** 3
# Out:
# 1728

# %%
pow(12 , 3)
# Out:
# 1728

# %%
pow(12,3 ,2)
# Out:
# 0

# %%
pow(12,3 ,5)
# Out:
# 3

# %%
pow(5,3)
# Out:
# 125

# %%
pow(base = 5, exp = 3)
# Out:
# 125

# %%
pow(exp = 3, base = 5)
# Out:
# 125

# %%
pow(3, 5)
# Out:
# 243

# %%
pow(base = 5, exp = 3, milad = 1) #Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-cebfcd93eb5e> in <module>
# ----> 1 pow(base = 5, exp = 3, milad = 1) #Error
#
# TypeError: 'milad' is an invalid keyword argument for pow()

# %% [markdown]
# # Variables

# %%
a = 5
b = 12

# %%
a + b
# Out:
# 17

# %%
a * 2
# Out:
# 10

# %%
a * b
# Out:
# 60

# %%
c = 15.65

# %%
c
# Out:
# 15.65

# %%
print(c)
# Out:
# 15.65

# %%
c * 2
# Out:
# 31.3

# %%
c * a * b
# Out:
# 939.0

# %%
c*a*b
# Out:
# 939.0

# %%
c*      a*b
# Out:
# 939.0

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# float

# %%
type(c*a*b)
# Out:
# float

# %%
c*a*b
# Out:
# 939.0

# %%
d = a*b*c
print(d)
type(d)
# Out:
# 939.0
# float

# %% [markdown]
# ## Rules

# %%
a *                b
# Out:
# 60

# %%
Arya = 5

# %%
Ar ya = 5
# Out:
#   File "<ipython-input-45-862d49112a1a>", line 1
#     Ar ya = 5
#        ^
# SyntaxError: invalid syntax

# %%
MYVARIABLE = 5

# %%
myvariable = 5

# %%
print('Hello')
# Out:
# Hello

# %%
print = 5

# %%
print
# Out:
# 5

# %%
print('Hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-21e7c95aa057> in <module>
# ----> 1 print('Hello')
#
# TypeError: 'int' object is not callable

# %%
#RESTART KENREL

# %%
#keywords not to use:
#int, float, str, print, len, .....

# %%
#Static Variable
#In c:
# int a = 5;
# a = 6; Error or not? No Error
# a = 7.2; >> Error or not? Error

# %%
a = 5
print(type(a))
print(a)
# Out:
# <class 'int'>
# 5

# %%
a = 'Ali'
print(type(a))
print(a)
# Out:
# <class 'str'>
# Ali

# %%
print(
    
'Ali'
    
    
)
# Out:
# Ali

# %%
print(
    
"Ali"
    
    
)
# Out:
# Ali

# %%
my_int = 123 #int
my_float = 456.789 #Float

# %%
d = int(my_float)
print(d)
print(type(d))
# Out:
# 456
# <class 'int'>

# %% [markdown]
# # Strings

# %%
my_string = 'Python Class'

# %%
print(my_string)
# Out:
# Python Class

# %%
my_string.isalpha()
# Out:
# False

# %%
my_string.isupper()
# Out:
# False

# %%
'PYTHON CLASS'.isupper()
# Out:
# True

# %%
my_string
# Out:
# 'Python Class'

# %%
my_string.lower()
# Out:
# 'python class'

# %%
my_string.upper()
# Out:
# 'PYTHON CLASS'

# %%
test = my_string.upper()

# %%
print(test)
# Out:
# PYTHON CLASS

# %%
print(my_string)
# Out:
# Python Class

# %%
my_string[0]
# Out:
# 'P'

# %%
my_string[5]
# Out:
# 'n'

# %%
my_string[6]
# Out:
# ' '

# %%
my_string[7]
# Out:
# 'C'
