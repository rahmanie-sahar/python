# %% [markdown]
# # List Comprehension

# %%
l1= [n**2 for n in range(6)]

# %%
l1
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
my_string = 'My name is Mike and I am 20 yrs old'

# %%
['MY','NAME',....]

# %%
[a.upper for a in 'my name'.split()]
# Out:
# [<function str.upper()>, <function str.upper()>]

# %%
my_string.split()
# Out:
# ['My', 'name', 'is', 'Mike', 'and', 'I', 'am', '20', 'yrs', 'old']

# %%
[n.upper() for n in my_string.split()]
# Out:
# ['MY', 'NAME', 'IS', 'MIKE', 'AND', 'I', 'AM', '20', 'YRS', 'OLD']

# %% [markdown]
# # Dictionary Comprehension

# %%
d1 = {0:0 , 1:1, 2:8, 3:27}

# %%
d2 = {n:n**3 for n in range(10)}

# %%
# Out:
# {0: 0, 1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729}

# %%
my_string = 'My name is Mike and I am 20 yrs old'

# %%
# key : vale >>>> WORD : length
# {'My': 2 , 'name':4 ......}

# %%
{n:len(n) for n in my_string.split()}
# Out:
# {'My': 2,
#  'name': 4,
#  'is': 2,
#  'Mike': 4,
#  'and': 3,
#  'I': 1,
#  'am': 2,
#  '20': 2,
#  'yrs': 3,
#  'old': 3}

# %%
my_list2 = ['string',1,2,3,1.2, 7.8]

# %%
{a: type(a) for a in my_list2}
# Out:
# {'string': str, 1: int, 2: int, 3: int, 1.2: float, 7.8: float}

# %%
type(my_list2)
# Out:
# list

# %% [markdown]
# # Python Casting

# %%
x = int(1)
y = int(1.5)
z = int( '3' )

# %%
type(1)
# Out:
# int

# %%
type(y)
# Out:
# int

# %%
y
# Out:
# 1

# %%
type(1.5)
# Out:
# float

# %%
type(z)
# Out:
# int

# %%
type('3')
# Out:
# str

# %%
a = '12345'

# %%
a[0]
# Out:
# '1'

# %%
a[4]
# Out:
# '5'

# %%
type(a)
# Out:
# str

# %%
b = int(a)

# %%
b
# Out:
# 12345

# %%
type(b)
# Out:
# int

# %%
b[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-54af0eb47770> in <module>
# ----> 1 b[0]
#
# TypeError: 'int' object is not subscriptable

# %%
str(789)
# Out:
# '789'

# %%
print(12 + 34)
print( str(12) + str(34)   )
# Out:
# 46
# 1234

# %%
'abcd' + 'efgh'
# Out:
# 'abcdefgh'

# %%
type(str(12) + str(34))
# Out:
# str

# %%
int(str(12) + str(34))
# Out:
# 1234

# %%
type(1 + 1.5)
# Out:
# float

# %%
1 + 1.5
# Out:
# 2.5

# %%
str(1234)
# Out:
# '1234'

# %%
int('abcd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-b6487b2c3886> in <module>
# ----> 1 int('abcd')
#
# ValueError: invalid literal for int() with base 10: 'abcd'

# %%
int('1234')
# Out:
# 1234

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %% [markdown]
# # If Else Elif

# %%
type('a') == str
# Out:
# True

# %% [markdown]
# ## Indentation

# %%
a = 5
b = 6

# %%
a = 5
    b = 6
# Out:
#   File "<ipython-input-63-f39aa874644c>", line 2
#     b = 6
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Statements

# %%
if 4>5 :
    print('This is a True statement.')
    print('Hello')
    a = 4 + 10
    my_list = [1,2,3]
print('HELLO!')
# Out:
# HELLO!

# %%
4>5
# Out:
# False

# %%
if 4<5 :
    print('This is a True statement.')
    print('Hello')
    a = 4 + 10
    my_list = [1,2,3]
print('HELLO!')
# Out:
# This is a True statement.
# Hello
# HELLO!

# %%
if True:
    print('Hello')
# Out:
# Hello

# %%
b = 200
a = 200

if b>a : #agar...
    print('b is greater than a')
else : #dar ghiere in soorat...
    print('a is greater than b')
# Out:
# a is greater than b

# %%
b = 200
a = 200

if b>a : #agar...
    print('b is greater than a 1111')
elif b<a : #else if >>> dar gheire in soorat, agar...
    print('a is greater than b  2222')
elif b == a :
    print('a is equal to b  3333')
# Out:
# a is equal to b  3333

# %%
b = 200
a = 200

if b>a : #agar...
    print('b is greater than a 1111')
elif b<a : #else if >>> dar gheire in soorat, agar...
    print('a is greater than b  2222')
else:
    print('a is equal to b  3333')
# Out:
# a is equal to b  3333

# %%
A = 'm'
#if >>> [elif] >>> [else]
if A == 'a':
    print('A is equal to a')
elif A == 'b':
    print('A is equal to b')
elif A == 'c':
    print('A is equal to c')
elif A == 'd':
    print('A is equal to d')
else :
    print("I don't know!")
   
print('END')
# Out:
# I don't know!
# END

# %%
b = 5

if b>100 :
    print('L1')
elif b>50:
    print('L2')
elif b>20:
    print('L3')
elif b>10:
    print('L4')
else :
    print('L5')
# Out:
# L5

# %%
b = 110

if b>100 :
    print('L1')
if b>50:
    print('L2')
elif b>20:
    print('L3')
elif b>10:
    print('L4')
else :
    print('L5')
# Out:
# L1
# L2

# %%
b = 110

if b>100 :
    print('L1')
if b>50:
    print('L2')
if b>20:
    print('L3')
if b>10:
    print('L4')
else :
    print('L5')
# Out:
# L1
# L2
# L3
# L4

# %% [markdown]
# # Short Hand if else

# %%
a= 5
b = 10
if b>a : print('b is greater than a')
# Out:
# b is greater than a

# %%
a= 5
b = 1
if b>a : print('b is greater than a')

# %%
a = 2
b = 330
print('A') if a>b else print('B')
# Out:
# B
