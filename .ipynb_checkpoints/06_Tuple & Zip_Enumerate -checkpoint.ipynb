# %% [markdown]
# # Tuples

# %%
my_tup = (1,2,3,4)

# %%
my_tup[0]
# Out:
# 1

# %%
my_tup[-1]
# Out:
# 4

# %%
my_tup2 = ('a', 'b','c','d',5)

# %%
my_tup2[2]
# Out:
# 'c'

# %%
my_tup2[2] = 'm'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-57c5e07a5b33> in <module>
# ----> 1 my_tup2[2] = 'm'
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tup2[::-1]
# Out:
# (5, 'd', 'c', 'b', 'a')

# %%
my_tup2.count('c')
# Out:
# 1

# %%
my_tup2.count('f')
# Out:
# 0

# %%
my_tup2
# Out:
# ('a', 'b', 'c', 'd', 5)

# %%
my_tup2.index('b')
# Out:
# 1

# %%
mylist = ['a',1,2,'AIR']

# %%
my_tup3 = tuple(mylist)

# %%
my_tup3
# Out:
# ('a', 1, 2, 'AIR')

# %%
my_tup2
# Out:
# ('a', 'b', 'c', 'd', 5)

# %%
new_list = list(my_tup2)

# %%
new_list
# Out:
# ['a', 'b', 'c', 'd', 5]

# %%
my_tup4 = ()

# %%
len(my_tup4)
# Out:
# 0

# %%
my_tup5 = (5)

# %%
type(my_tup5)
# Out:
# int

# %%
my_tup = (5,)

# %%
type(my_tup)
# Out:
# tuple

# %% [markdown]
# # Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-724ba28f4a9a> in <module>
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
a = True

# %%
type(a)
# Out:
# bool

# %%
a = 0 #False in boolean
b = 15 #True in boolean

# %%
bool(a)
# Out:
# False

# %%
bool(b)
# Out:
# True

# %%
bool(16)
# Out:
# True

# %%
bool(50)
# Out:
# True

# %%
bool(15.6)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('mystring')
# Out:
# True

# %% [markdown]
# # Logic

# %%
a = 1
b = 5

# %%
a == b
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
2 == 2
# Out:
# True

# %%
2 == 3
# Out:
# False

# %%
a = 1
b = 5

# %%
a != b
# Out:
# True

# %%
a =! b

# %%
a
# Out:
# ["'b' is not recognized as an internal or external command,",
#  'operable program or batch file.']

# %%
a <> b
# Out:
#   File "<ipython-input-58-7450b63d9fd5>", line 1
#     a <> b
#        ^
# SyntaxError: invalid syntax

# %%
a != b #barabar naboodan
# Out:
# True

# %%
a == b #barabar boodan
# Out:
# False

# %%
3 > 2
# Out:
# True

# %%
3 < 2
# Out:
# False

# %%
3 > 3
# Out:
# False

# %%
3 >= 3
# Out:
# True

# %%
# and , or

# %%
a = 3 > 2
print(a)
# Out:
# True

# %%
b = 15<= 45
print(b)
# Out:
# True

# %%
#and : if both are true
#or  : if at least one is true

# %%
5>4 and 8<16
# Out:
# True

# %%
5>4 and 8>16
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
True and True and True and True and 5<1
# Out:
# False

# %%
# in, is, not

# %%
'm' in 'My name is Milad'
# Out:
# True

# %%
type('m' in 'My name is Milad')
# Out:
# bool

# %%
'a' in ['a','b',[4,5,6],5 ,'7']
# Out:
# True

# %%
'c' in ['a','b',[4,5,6],5 ,'7']
# Out:
# False

# %%
5 in ['a','b',[4,5,6],5 ,'7']
# Out:
# True

# %%
4 in ['a','b',[4,5,6],5 ,'7']
# Out:
# False

# %%
#is

# %%
l1 = [1,2,3,4]
l2 = [1,2,3,4]
l3 = l1
l4 = l1.copy()

# %%
5 == 5
# Out:
# True

# %%
l1 == l2
# Out:
# True

# %%
l1 is l2
# Out:
# False

# %%
l1 is l3
# Out:
# True

# %%
l1 is l4
# Out:
# False

# %%
not True
# Out:
# False

# %%
l1 is not l4
# Out:
# True

# %%
all([True, True])
# Out:
# True

# %%
all([True, True, False])
# Out:
# False

# %%
any([True, True, False])
# Out:
# True

# %% [markdown]
# # Zip, Enumerate

# %% [markdown]
# ## Zip

# %%
x = ['a','b','c','d']
y = ['x','y','z','o']

# %%
x
# Out:
# ['a', 'b', 'c', 'd']

# %%
y
# Out:
# ['x', 'y', 'z', 'o']

# %%
zip(x,y)

# %%
list(zip(x,y))
# Out:
# [('a', 'x'), ('b', 'y'), ('c', 'z'), ('d', 'o')]

# %%
z = [5,6,10,15]

# %%
list(zip(x,y,z))
# Out:
# [('a', 'x', 5), ('b', 'y', 6), ('c', 'z', 10), ('d', 'o', 15)]

# %%
x = [0,1,2,3]
y = ['x','y','z','o']
list(zip(x,y))
# Out:
# [(0, 'x'), (1, 'y'), (2, 'z'), (3, 'o')]

# %% [markdown]
# ## Enumerate

# %%
y = ['x','y','z','o']
list(enumerate(y))
# Out:
# [(0, 'x'), (1, 'y'), (2, 'z'), (3, 'o')]

# %% [markdown]
# # List Comprehention

# %%
A = [1,2,3,5,10,15,200]

# %%
# in for

# %%
B = [n**2 for n in A]

# %%
B
# Out:
# [1, 4, 9, 25, 100, 225, 40000]

# %%
[asghar**3 for asghar in A]
# Out:
# [1, 8, 27, 125, 1000, 3375, 8000000]

# %%
[ _**3 for _ in A]
# Out:
# [1, 8, 27, 125, 1000, 3375, 8000000]

# %%
[n**2 for n in range(10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
[n**2 for n in list(range(10))]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
from math import sqrt

# %%
[n**0.5 for n in range(6)]
# Out:
# [0.0, 1.0, 1.4142135623730951, 1.7320508075688772, 2.0, 2.23606797749979]

# %%
[10*sqrt(n) for n in range(6)]
# Out:
# [0.0, 10.0, 14.142135623730951, 17.32050807568877, 20.0, 22.360679774997898]

# %%
A = [6,7,8,9,10]
B = [1,10,25,0,7]

# %%
list(zip(A,B))
# Out:
# [(6, 1), (7, 10), (8, 25), (9, 0), (10, 7)]

# %%
c = [a-b for a,b in list(zip(A,B))]

# %%
c
# Out:
# [5, -3, -17, 9, 3]

# %%
list(zip(A,B))[0]
# Out:
# (6, 1)

# %%
[n for n in list(zip(A,B))]
# Out:
# [(6, 1), (7, 10), (8, 25), (9, 0), (10, 7)]

# %%
import numpy as np

# %%
A = np.array([2,5,7,6,15])
B = np.array([1,5,6,12,11])

# %%
B
# Out:
# array([ 1,  5,  6, 12, 11])

# %%
A
# Out:
# array([ 2,  5,  7,  6, 15])

# %%
A - B
# Out:
# array([ 1,  0,  1, -6,  4])

# %%
A*B
# Out:
# array([  2,  25,  42,  72, 165])

# %%
A + B
# Out:
# array([ 3, 10, 13, 18, 26])

# %%
A ** B
# Out:
# array([          2,        3125,      117649, -2118184960,  -308274769],
#       dtype=int32)
