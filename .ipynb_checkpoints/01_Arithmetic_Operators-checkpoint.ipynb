# %% [markdown]
# My first code.

# %%
print("Hello World")
# Out:
# Hello World

# %%
#Summation
1+2
# Out:
# 3

# %%
5+7
# Out:
# 12

# %%
#Subtraction
3-1
# Out:
# 2

# %%
3 * 2
# Out:
# 6

# %%
10 / 2
# Out:
# 5.0

# %%
9/2
# Out:
# 4.5

# %%
5 ** 2
# Out:
# 25

# %%
25 ** 0.5
# Out:
# 5.0

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10 % 3
# Out:
# 1

# %%
10 + 4 / 2
# Out:
# 12.0

# %%
(10 + 4) / 2
# Out:
# 7.0

# %%
(1 + 6) * (2 + 3) / 3
# Out:
# 11.666666666666666

# %%
4 * 5 ** 2
#400 or 100?
# Out:
# 100

# %%
1 + 2
2 * 10
7 / 4
5 ** 2
# Out:
# 25

# %%
print(1 + 2)
print(2 * 10)
print(7 / 4)
print(5 ** 2)
# Out:
# 3
# 20
# 1.75
# 25

# %%
#Absolute Value
print(abs(5))
print(abs(-5))
# Out:
# 5
# 5

# %%
abs(-10.15)
# Out:
# 10.15

# %%
#rounding
round(15.2)
# Out:
# 15

# %%
round(15.8)
# Out:
# 16

# %%
round(15.1234)
# Out:
# 15

# %%
round(15.1234, 3)
# Out:
# 15.123

# %%
round(15.1234, 2)
# Out:
# 15.12

# %%
round(123456.123456, 2)
# Out:
# 123456.12

# %%
round(123456, -1)
# Out:
# 123460

# %%
round(123456, -2)
# Out:
# 123500

# %%
round(123456, -3)
# Out:
# 123000
