# %% [markdown]
# # Dictionary

# %%
#Key >>> Value
#Book >> Ketab
#ID >> 96411234
#Age >>> 25
#Capital >>> Tehran

# %%
my_dict1 = {'Name':'Mike' , 'Age':25, 'Sex':'Male' , 'Tel': 9121234567}

# %%
my_dict1
# Out:
# {'Name': 'Mike', 'Age': 25, 'Sex': 'Male', 'Tel': 9121234567}

# %%
my_dict1['Age']
# Out:
# 25

# %%
my_dict1['Tel']
# Out:
# 9121234567

# %%
my_dict1['Name']
# Out:
# 'Mike'

# %%
my_dict = {'Esm':'Pride', 'Year':2015}

# %%
my_dict
# Out:
# {'Esm': 'Pride', 'Year': 2015}

# %%
mylist = [{'Name':'Akbar', 'Age':45} , {'Name':'Arya', 'Age':25}]

# %%
mylist
# Out:
# [{'Name': 'Akbar', 'Age': 45}, {'Name': 'Arya', 'Age': 25}]

# %%
mylist[1]['Name']
# Out:
# 'Arya'

# %%
my_dict1 = {'Name':'Mike' , 'Age':25, 'Sex':'Male' , 'Tel': 9121234567}

# %%
my_dict1
# Out:
# {'Name': 'Mike', 'Age': 25, 'Sex': 'Male', 'Tel': 9121234567}

# %%
my_dict1['Last Name'] = 'Johnson'

# %%
my_dict1
# Out:
# {'Name': 'Mike',
#  'Age': 25,
#  'Sex': 'Male',
#  'Tel': 9121234567,
#  'Last Name': 'Johnson'}

# %%
my_dict1.clear()

# %%
my_dict1
# Out:
# {}

# %%
my_dict1 = {'Name':'Mike' , 'Age':25, 'Sex':'Male' , 'Tel': 9121234567}

# %%
my_dict1
# Out:
# {'Name': 'Mike', 'Age': 25, 'Sex': 'Male', 'Tel': 9121234567}

# %%
my_dict1.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7c823e17ca8a> in <module>
# ----> 1 my_dict1.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
my_dict1.pop('Name')
# Out:
# 'Mike'

# %%
my_dict1
# Out:
# {'Age': 25, 'Sex': 'Male', 'Tel': 9121234567}

# %%
my_dict1
# Out:
# {'Age': 25, 'Sex': 'Male', 'Tel': 9121234567}

# %%
my_dict1['Age']
# Out:
# 25

# %%
my_dict1.keys()
# Out:
# dict_keys(['Age', 'Sex', 'Tel'])

# %%
my_dict1.values()
# Out:
# dict_values([25, 'Male', 9121234567])

# %% [markdown]
# # Sets

# %%
# {1,1,1,1,1,2,3,4} >>>> {1,2,3,4}

# %%
my_set = {1,2,3,4,5}

# %%
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set = {1,1,1,1,1,2,3,3,3,4,5,5}

# %%
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
len(my_set)
# Out:
# 5

# %%
{1,1,1,1,1}
# Out:
# {1}

# %%
[1,1,1,1,1]
# Out:
# [1, 1, 1, 1, 1]

# %%
my_set[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-158c424478a1> in <module>
# ----> 1 my_set[0]
#
# TypeError: 'set' object is not subscriptable

# %%
my_set = {'a', 'b' , 'd', 'e','f'}

# %%
my_set
# Out:
# {'a', 'b', 'd', 'e', 'f'}

# %%
my_set.add('M')

# %%
my_set
# Out:
# {'M', 'a', 'b', 'd', 'e', 'f'}

# %%
my_set.add('c')

# %%
my_set
# Out:
# {'M', 'a', 'b', 'c', 'd', 'e', 'f'}

# %%
my_set.add(1)

# %%
my_set
# Out:
# {1, 'M', 'a', 'b', 'c', 'd', 'e', 'f'}

# %%
my_set.pop()
# Out:
# 'e'

# %%
my_set
# Out:
# {1, 'M', 'a', 'b', 'c', 'd', 'f'}

# %%
my_set.pop(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-dbff14e75fff> in <module>
# ----> 1 my_set.pop(5)
#
# TypeError: pop() takes no arguments (1 given)

# %%
my_set
# Out:
# {1, 'M', 'a', 'b', 'c', 'd', 'f'}

# %%
my_set.remove('b')

# %%
my_set
# Out:
# {1, 'M', 'a', 'c', 'd', 'f'}

# %%
[1,2,3,4] - [1,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-bf0ea9e52fd1> in <module>
# ----> 1 [1,2,3,4] - [1,2]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
A = {1,2,3,4,5}
B = {2,3}

# %%
A - B
# Out:
# {1, 4, 5}

# %%
[1,2,3,4] + [1,2]
# Out:
# [1, 2, 3, 4, 1, 2]

# %%
A + B
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-151064de832d> in <module>
# ----> 1 A + B
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
5 * A
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-f9b41bd98147> in <module>
# ----> 1 5 * A
#
# TypeError: unsupported operand type(s) for *: 'int' and 'set'

# %%
# Tafrigh (-)   Eshterak(Intersection)  Ejtema(Union)

# %%
A = {1,2,3,4,5}
B = {2,3,6,7}

# %%
A
# Out:
# {1, 2, 3, 4, 5}

# %%
B
# Out:
# {2, 3, 6, 7}

# %%
#Union
A+B
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-931d13d8fd14> in <module>
#       1 #Union
# ----> 2 A+B
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
A | B
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
A.intersection(B)
# Out:
# {2, 3}

# %%
A & B
# Out:
# {2, 3}

# %%
B.union(A)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
B.intersection(A)
# Out:
# {2, 3}

# %%
A - B
# Out:
# {1, 4, 5}

# %%
B - A
# Out:
# {6, 7}

# %%
A.difference(B) #A-B
# Out:
# {1, 4, 5}

# %%
B.difference(A) #B-A
# Out:
# {6, 7}

# %%
A
# Out:
# {1, 2, 3, 4, 5}

# %%
B
# Out:
# {2, 3, 6, 7}

# %%
A ^ B
# Out:
# {1, 4, 5, 6, 7}

# %%
B ^ A
# Out:
# {1, 4, 5, 6, 7}

# %%
[1,2,3,4,4,5,6,6,6,6]
# Out:
# [1, 2, 3, 4, 4, 5, 6, 6, 6, 6]

# %%
set([1,2,3,4,4,5,6,6,6,6])
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set('ABCCCDDDEFG')
# Out:
# {'A', 'B', 'C', 'D', 'E', 'F', 'G'}

# %%
list('ABCCCDDDEFG')
# Out:
# ['A', 'B', 'C', 'C', 'C', 'D', 'D', 'D', 'E', 'F', 'G']
