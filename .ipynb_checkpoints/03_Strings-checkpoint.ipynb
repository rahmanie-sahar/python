# %%
s = "ABCDEFG"

# %%
len(s)
# Out:
# 7

# %% [markdown]
# # Indexing

# %%
s[0]
# Out:
# 'A'

# %%
s[2]
# Out:
# 'C'

# %%
s[6]
# Out:
# 'G'

# %%
s[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-b035325af127> in <module>
# ----> 1 s[7]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'ABCDEFG'

# %%
s[-1]
# Out:
# 'G'

# %%
s[-2]
# Out:
# 'F'

# %%
s[-3]
# Out:
# 'E'

# %%
s2 = 'AIR Center'

# %%
s2[3]
# Out:
# ' '

# %% [markdown]
# # Slicing

# %%
s = "ABCDEFGHIJKLMNO"

# %%
len(s)
# Out:
# 15

# %%
s[0 : 4] #indices : 0,1,2,3 not 4
# Out:
# 'ABCD'

# %%
s[4]
# Out:
# 'E'

# %%
s[1:2]
# Out:
# 'B'

# %%
'I'm a student'
# Out:
#   File "<ipython-input-22-32e8d5b0caa3>", line 1
#     'I'm a student'
#        ^
# SyntaxError: invalid syntax

# %%
"I'm a student"
# Out:
# "I'm a student"

# %%
s[1]
# Out:
# 'B'

# %%
s[1:2]
# Out:
# 'B'

# %%
s
# Out:
# 'ABCDEFGHIJKLMNO'

# %% [markdown]
# adade sahih (1,5) : 2,3,4
# adade sahih [1,5] : 1,2,3,4,5
# adade sahih [1,5) : 1,2,3,4

# %%
s[4:7]
# Out:
# 'EFG'

# %%
s2 = "I'm a student"

# %%
s2[1]
# Out:
# "'"

# %%
s2[0:5]
# Out:
# "I'm a"

# %%
s
# Out:
# 'ABCDEFGHIJKLMNO'

# %%
s[0:10:2]
# Out:
# 'ACEGI'

# %%
s[5]
# Out:
# 'F'

# %%
s[5:12]
# Out:
# 'FGHIJKL'

# %%
s[5:12:2]
# Out:
# 'FHJL'

# %%
s
# Out:
# 'ABCDEFGHIJKLMNO'

# %%
len(s)
# Out:
# 15

# %%
# Char c to the end
s[2:15]
# Out:
# 'CDEFGHIJKLMNO'

# %%
# Char c to the end
s[2:]
# Out:
# 'CDEFGHIJKLMNO'

# %%
s[:8]
# Out:
# 'ABCDEFGH'

# %%
s[0:2] + s[3:]
# Out:
# 'ABDEFGHIJKLMNO'

# %%
s[1:10:2]
# Out:
# 'BDFHJ'

# %%
s[::1]
# Out:
# 'ABCDEFGHIJKLMNO'

# %%
s[::2]
# Out:
# 'ACEGIKMO'

# %%
s[::3]
# Out:
# 'ADGJM'

# %%
s[::-1]
# Out:
# 'ONMLKJIHGFEDCBA'

# %%
s1 = 'abcd'
s2 = 'efgh'

# %%
s1 + s2
# Out:
# 'abcdefgh'

# %%
s1 + ' ' + s2
# Out:
# 'abcd efgh'

# %%
5 * s1
# Out:
# 'abcdabcdabcdabcdabcd'

# %%
s1 - s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-375f7a57ef9a> in <module>
# ----> 1 s1 - s2
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
s1 - s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-2ddef79a41d0> in <module>
# ----> 1 s1 - s1
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
s1 ** 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-5115c8ca6d00> in <module>
# ----> 1 s1 ** 2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
s1 /2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-4b42d7b15ecf> in <module>
# ----> 1 s1 /2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# # Immutable

# %%
s = 'Adobe'

# %%
s = 'Connect'

# %%
s #correct
# Out:
# 'Connect'

# %%
s = 'Adobe'

# %%
s[1] = 'm'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-d9973159c35a> in <module>
# ----> 1 s[1] = 'm'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # Methods

# %%
my_string = 'adobe connect'

# %%
my_string
# Out:
# 'adobe connect'

# %%
my_string.capitalize()
# Out:
# 'Adobe connect'

# %%
my_string
# Out:
# 'adobe connect'

# %%
a = 5

# %%
a = a * 3

# %%
a
# Out:
# 15

# %%
my_string
# Out:
# 'adobe connect'

# %%
my_string.upper()
# Out:
# 'ADOBE CONNECT'

# %%
'Adobe'.upper()
# Out:
# 'ADOBE'

# %%
new_string = 'Adobe'.upper()

# %%
new_string
# Out:
# 'ADOBE'

# %%
name = 'Ali Yazdani'

# %%
name.istitle()
# Out:
# True

# %%
name = 'Ali yazdani'

# %%
name.istitle()
# Out:
# False

# %%
name
# Out:
# 'Ali yazdani'

# %%
name.title()
# Out:
# 'Ali Yazdani'

# %%
'Heavy sanctions on Iran'.title()
# Out:
# 'Heavy Sanctions On Iran'

# %%
s = 'Heavy sanctions on Iran'

# %%
s.replace('Iran', 'Syria')
# Out:
# 'Heavy sanctions on Syria'

# %%
name = '00001.img.school'

# %%
name.replace('.', '')
# Out:
# '00001imgschool'

# %%
name.replace('.','_')
# Out:
# '00001_img_school'

# %%
s
# Out:
# 'Heavy sanctions on Iran'

# %%
s.find('s')
# Out:
# 6

# %%
s.count('s')
# Out:
# 2

# %%
s.count('S')
# Out:
# 0

# %%
s.count('e')
# Out:
# 1

# %%
print('abc')
print('123')
print('abc123')
print('@#$%%^&*(15)')
# Out:
# abc
# 123
# abc123
# @#$%%^&*(15)

# %%
s= 'abc'

# %%
s.isalpha()
# Out:
# True

# %%
'123'.isalpha()
# Out:
# False

# %%
s = 'AIR Center 12345'

# %%
s.isalpha()
# Out:
# False

# %%
s.isnumeric()
# Out:
# False

# %%
s.isalnum()
# Out:
# False

# %%
s = 'AIRCenter12345'
s.isalnum()
# Out:
# True

# %%
s = '   Arya   '

# %%
s.rstrip()
# Out:
# '   Arya'

# %%
s.lstrip()
# Out:
# 'Arya   '

# %%
s.lstrip().rstrip()
# Out:
# 'Arya'

# %%
s.strip()
# Out:
# 'Arya'

# %%
email = 'soltani_m@iust.ac.ir'

# %%
email.split('@')
# Out:
# ['soltani_m', 'iust.ac.ir']

# %%
s = '2020_01_20-14_22_30'

# %%
s.split("-")[0]
# Out:
# '2020_01_20'

# %%
s.split('_')
# Out:
# ['2020', '01', '20-14', '22', '30']

# %% [markdown]
# # Formatting

# %%
name = 'Sajjad'
Age = 25

# %%
"Hello my name is Sajjad, and I'm 25 years old"
# Out:
# "Hello my name is Sajjad, and I'm 25 years old"

# %%
"Hello my name is ____ , and I'm _____ years old"
# Out:
# "Hello my name is ____ , and I'm _____ years old"

# %%
"Hello my name is {} , and I'm {} years old".format(name, Age)
# Out:
# "Hello my name is Sajjad , and I'm 25 years old"

# %%
name = 'Milad'
Age = 120
"Hello my name is {} , and I'm {} years old".format(name, Age)
# Out:
# "Hello my name is Milad , and I'm 120 years old"

# %%
"Hello my name is {} , and I'm {} years old"
# Out:
# "Hello my name is {} , and I'm {} years old"

# %%
city = 'London'
temp = 20
"Temperature in {} is {} degrees".format(city, temp)
# Out:
# 'Temperature in London is 20 degrees'

# %%
city = 'London'
temp = 20
"Temperature in {} is {} degrees".format(temp, city)
# Out:
# 'Temperature in 20 is London degrees'

# %%
city = 'London'
temp = 20
"Temperature in {c} is {t} degrees".format(c = city, t = temp)
# Out:
# 'Temperature in London is 20 degrees'

# %%
city = 'London'
temp = 20
"Temperature in {c} is {t} degrees".format(t = temp, c = city)
# Out:
# 'Temperature in London is 20 degrees'

# %%
"Temperature in {c} is {t} degrees".format(t = 200, c = 'Hell')
# Out:
# 'Temperature in Hell is 200 degrees'

# %%
type(s)
# Out:
# str

# %%
type(5)
# Out:
# int

# %%
type(5.0)
# Out:
# float
