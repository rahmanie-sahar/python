# %% [markdown]
# # Definition
#
# Recursion means "defining a problem in terms of itself". This can be a very powerful tool in writing algorithms. Recursion comes directly from Mathematics, where there are many examples of expressions written in terms of themselves.

# %% [markdown]
# ### Fibonatchi Algorithm
# f(x) = f(x-1) + f(x-2)

# %%
def fibonatichi(x):
    if x==0:
        return 0
    elif x==1:
        return 1
    else:
        return fibonatichi(x-1) + fibonatichi(x-2)

# %%
fibonatichi(9)
# Out:
# 34

# %% [markdown]
# ## Factorial
# f(x) = x * f(x-1)

# %%
def factorial(x):
    if x==1:
        return 1
    else:
        return x * factorial(x-1)

# %%
factorial(6)
# Out:
# 720
